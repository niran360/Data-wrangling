# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
cell_url = "https://raw.githubusercontent.com/zalihat/cell_phone_dataset/master/cell_phones.csv"
pop_url = "https://raw.githubusercontent.com/zalihat/cell_phone_dataset/master/population1.csv"
geo_url = "https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv"

# %%
df_cell = pd.read_csv(cell_url)
df_pop = pd.read_csv(pop_url)
df_geo = pd.read_csv(geo_url)

# %%
df_geo.head()
# Out:
#   country g77_and_oecd_countries income_3groups        income_groups  \
# 0    abkh                 others            NaN                  NaN
# 1     abw                 others    high_income          high_income
# 2     afg                    g77     low_income           low_income
# 3     ago                    g77  middle_income  lower_middle_income
# 4     aia                 others            NaN                  NaN
#
#    is--country iso3166_1_alpha2 iso3166_1_alpha3  iso3166_1_numeric iso3166_2  \
# 0         True              NaN              NaN                NaN       NaN
# 1         True               AW              ABW              533.0       NaN
# 2         True               AF              AFG                4.0       NaN
# 3         True               AO              AGO               24.0       NaN
# 4         True               AI              AIA              660.0       NaN
#
#    landlocked  ...  longitude  main_religion_2008         name  \
# ...

# %%
df_cell_pop = pd.merge(df_cell,df_pop,on=['Country',"year"])

# %%
df_cell_pop.head()
# Out:
#        Country  year  cell_phones_total  population
# 0  Afghanistan  1960                0.0     9000000
# 1  Afghanistan  1961                0.0     9170000
# 2  Afghanistan  1962                0.0     9350000
# 3  Afghanistan  1963                0.0     9540000
# 4  Afghanistan  1964                0.0     9740000

# %%
df_geo.rename(columns={'country': 'geo', 'name': 'Country'}, inplace=True)

# %%
df_geo[['geo', 'Country']]  # df2 but only with columns x, a, and b

df_cell_pop=df_cell_pop.merge(df_geo[['geo', 'Country']])

# %%
df_cell_pop.shape
# Out:
# (11640, 5)

# %%
df_cell_pop["cell_per_person"] = df_cell_pop["cell_phones_total"]/df_cell_pop["population"]

# %%
# c=df_cell_pop.groupby(["cell_per_person","Country"])
# c.head()
df_cell_pop.loc[df_cell_pop.cell_per_person == 1.2]
# Out:
#               Country  year  cell_phones_total  population  geo  \
# 11087  United Kingdom  2007         73800000.0    61500000  gbr
#
#        cell_per_person
# 11087              1.2

# %%
df_cell_pop.loc[df_cell_pop.Country == "United States"]
# Out:
#              Country  year  cell_phones_total  population  geo  \
# 11100  United States  1960                0.0   187000000  usa
# 11101  United States  1961                0.0   190000000  usa
# 11102  United States  1962                0.0   192000000  usa
# 11103  United States  1963                0.0   195000000  usa
# 11104  United States  1964                0.0   197000000  usa
# 11105  United States  1965                0.0   200000000  usa
# 11106  United States  1966                0.0   202000000  usa
# 11107  United States  1967                0.0   204000000  usa
# 11108  United States  1968                0.0   206000000  usa
# 11109  United States  1969                0.0   208000000  usa
# 11110  United States  1970                0.0   210000000  usa
# 11111  United States  1971                0.0   211000000  usa
# 11112  United States  1972                0.0   213000000  usa
# 11113  United States  1973                0.0   215000000  usa
# ...

# %%
# ((df_cell_pop['cell_per_person'] == 1.230769) & (df_cell_pop['year'] == 2017)).any()
# data.loc[(data.age >= 12), ['city', 'gender']]
# df_cell_pop.loc[(df_cell_pop.cell_per_person == 1.23), ['Country', 'year']]

# %%
# df_cell_pop['geo'] = map(str.upper, df_cell_pop['geo'])
#  = map(lambda x: str(x).upper(), df_cell_pop['geo'])
df_cell_pop['geo']
# Out:
# 0        <map object at 0x000002C7DF8E3988>
# 1        <map object at 0x000002C7DF8E3988>
# 2        <map object at 0x000002C7DF8E3988>
# 3        <map object at 0x000002C7DF8E3988>
# 4        <map object at 0x000002C7DF8E3988>
#                         ...
# 11635    <map object at 0x000002C7DF8E3988>
# 11636    <map object at 0x000002C7DF8E3988>
# 11637    <map object at 0x000002C7DF8E3988>
# 11638    <map object at 0x000002C7DF8E3988>
# 11639    <map object at 0x000002C7DF8E3988>
# Name: geo, Length: 11640, dtype: object
